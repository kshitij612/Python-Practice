# %%
a = None 
type(a)
# Out:
# NoneType

# %%
len()
# Out:
# 'sdfashfl'

# %%
def hit():
    '''hldskjfhdsklhfloskh'''
    print(2)

# %%
hit()
# Out:
# 2

# %%
s = '  pYTHON 1232 is a programming language.  '
s.upper()
# Out:
# '  PYTHON 1232 IS A PROGRAMMING LANGUAGE.  '

# %%
s.lower()
# Out:
# '  python 1232 is a programming language.  '

# %%
s.capitalize()
# Out:
# '  python 1232 is a programming language.  '

# %%
s.title()
# Out:
# '  Python 1232 Is A Programming Language.  '

# %%
s.isupper()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.isdigit()
# Out:
# False

# %%
s.count('pYTHON')
# Out:
# 1

# %%
s.lstrip()
# Out:
# 'pYTHON 1232 is a programming language.  '

# %%
s.rstrip()
# Out:
# '  pYTHON 1232 is a programming language.'

# %%
s.strip()
# Out:
# 'pYTHON 1232 is a programming language.'

# %% [markdown]
# # LISTS

# %%
ls = [1,2,3,4]  
# homogeneous list

# %%
type(ls)
# Out:
# list

# %%
list()
# Out:
# []

# %%
ls = [1, 'hit']

# %%
ls[1] = 'hello'
ls
# Out:
# [1, 'hello']

# %%
st = 'hello sdg'
st[1] = hit
#str is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 st = 'hello sdg'
# ----> 2 st[1] = hit
#       3 #str is immutable
#
# TypeError: 'str' object does not support item assignment

# %%
ls.append(5)
ls
#adds only one element
# Out:
# [1, 'hello', 5, 5, 5, 6, 5, 6, 5]

# %%
ls.extend([5,6])
ls
# Out:
# [1, 'hello', 5, 5, 5, 6, 5, 6, 5, 5, 6]

# %%
ls.insert(1,2)
ls
# Out:
# [1, 2, 2, 'hello', 5, 5, 5, 6, 5, 6, 5, 5, 6]

# %%
ls.remove(5)
ls
# Out:
# [1, 2, 'hello', 6, 5, 6, 5, 5, 6]

# %%
ls.pop(-1)
ls
#removes element using index
#default index -1
# Out:
# [1, 2, 'hello', 6, 5, 6, 5]

# %%
ls.clear()
#clears all elements and returns empty list

# %%
ls.index(5)
# Out:
# 4

# %%
ls.count(5)
# Out:
# 2

# %%
ls[2]= 2

# %%
ls.sort(reverse =True)
ls
# Out:
# [6, 6, 5, 5, 2, 2, 1]

# %% [markdown]
# # TUPLE

# %%
t = (1,2,3)
type(t)
# Out:
# tuple

# %%
tuple()
# Out:
# ()

# %%
t[1]
# Out:
# 2

# %%
t[1]=20
#tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 t[1]=20
#       2 #tuple is immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(0)
# Out:
# 0

# %%
t.index(3)
# Out:
# 2

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# # DICTIONARY

# %%
d = {100:1, 1:1, 2:2}
d
#KEY should be immutable type
# Out:
# {100: 1, 1: 1, 2: 2}

# %%
type(d)
# Out:
# dict

# %%
dict()
# Out:
# {}

# %%
d[100]=1000
d
# Out:
# {100: 1000, 1: 1, 2: 2}

# %%
d.get(1000, 'VALUE NOT PRESENT')
# Out:
# 'VALUE NOT PRESENT'

# %%
d.keys()
# Out:
# dict_keys([100, 1, 2])

# %%
d.values()
# Out:
# dict_values([1000, 1, 2])

# %%
d.items()
# Out:
# dict_items([(100, 1000), (1, 1), (2, 2)])

# %%
d.pop(2)
d
# Out:
# 2

# %%
d.clear()

# %% [markdown]
# # SET
# Unordered and mutable collection of mutable values

# %%
s1 = set()
type(s1)
# Out:
# set

# %%
s1.add(2)
s1.add(3)
s1
# Out:
# {2, 3}

# %%
s2 = {10.0,20.0,2,3,4,5,6,1,2,3}
s2
# Out:
# {1, 2, 3, 4, 5, 6, 10.0, 20.0}

# %%
type(s2)
# Out:
# set

# %%
set()
# Out:
# set()

# %%
s1.add(80)
s1
# Out:
# {2, 3, 45, 80}

# %%
s2 = s1.copy()
#deep copy
s2
# Out:
# {2, 3, 45}

# %%
s2.pop()
#removes 1st element if float or int 
#removes random element if any hetrogeneous value
s2
# Out:
# {4, 5, 6, 10.0, 20.0}

# %%
s2.remove(20)
#error if element not present
s2
# Out:
# {1, 2, 3, 4, 5, 6, 10.0}

# %%
s2.discard(20)
#no error if elemnt not present                                                  
s2
# Out:
# {1, 2, 3, 4, 5, 6, 10.0}

# %% [markdown]
# # OPERATORS

# %%
2 and 3
#both true then 2nd is answer
# Out:
# 3

# %%
2 or 3
#both true then 1st is answer
# Out:
# 2

# %%
2 and 2
# Out:
# 2

# %%
3 in {2:3,3:5}
#works only in collections
# Out:
# True

# %%
bin(10)
# Out:
# '0b1010'

# %%
hex(10)
# Out:
# '0xa'

# %%
3 & 2
# Out:
# 2

# %%
20 ^ 30
# Out:
# 10

# %%
2 | 3
# Out:
# 3

# %%
~2
# Out:
# -3

# %%
r = [1,2,3]
s = r
t = [1,2,3]

r is s
# Out:
# True

# %%
r is t
# Out:
# False

# %% [markdown]
# # INPUT

# %%
var = input("msg")
var
# Out:
# 'hellp'

# %%
type(var)
# Out:
# str

# %%
#eval fucntion is used to directly assign the data type
a = eval(input("Enter a value: "))
a
# Out:
# [1, 2, 3]

# %%
type(a)
# Out:
# list

# %%
b = eval(input("Enter a value:"))
b
# Out:
# {1, 2, 3}

# %%
type(b)
# Out:
# set

# %% [markdown]
# # CONDITIONAL STATEMENTS

# %%
num = int(input("Enter a number: "))
if(num % 3 == 0 and num % 5 ==0):
    print(num)
# Out:
# 15

# %%
age = int(input("Enter your age: "))
if(age >= 18 and age <= 25):
    print("Eligible to Vote")
# Out:
# Eligible to Vote

# %%
num = int(input("Enter a number:"))
if(num >= 0):
    print("Positive Number")
else:
    print("Negative Number")
# Out:
# Positive Number

# %%
marks = int(input("Enter a number:"))
if(marks >= 90):
    print("A")
elif(marks >= 75):
    print("B")
elif(marks >= 60):
    print("C")
elif(marks < 60):
    print("Fail")
# Out:
# Fail

# %%
ch = str(input("Enter a character: "))
if(ch.isupper()):
    print("Uppercase Letter")
elif(ch.islower()):
    print("Lowercase letter")
elif(ch.isdigit()):
    print("Digit")
else:
    print("Special Character")
# Out:
# Special Character

# %%
exp = int(input("Enter your experience: "))
rating = int(input("Enter your rating: "))
if (exp >= 5):
    if (rating >= 4):
        print("20% Bonus")
    else:
        print("10% Bonus")
else:
    print("No Bonus")
# Out:
# 20% Bonus

# %%
num = int(input("Enter a number:"))
if(num >= 0):
    if(num % 2 == 0):
        print("Even")
    else:
        print("Odd")
else:
    print("Negative Number")
# Out:
# Even

# %%
pin = int(input("Enter your pin:"))
bal = 1000
if(pin == 0000):
    withdrawl = int(input("Enter amount you want to withdraw: "))
    if(bal >= withdrawl):
        print("Transaction Successfull")
    else:
        print("Insufficient Balance")
else:
    print("Invalid Pin")
# Out:
# Insufficient Balance
